# %%
k1=input("enter first key : ")
k2=input("enter second key : ")
k3=input("enter third key : ")
k4=input("enter fourth key : ")
k5=input("enter fifth key : ")
v1=input("enter first value : ")
v2=input("enter second value : ")
v3=input("enter third value : ")
v4=input("enter fourth value : ")
v5=input("enter fifth value : ")
d={}
d[k1]=v1
d[k2]=v2
d[k3]=v3
d[k4]=v4
d[k5]=v5
l=list(d.items())   
l.sort() 
print("ascending order is : ",l)
l=list(d.items())
l.sort(reverse = True)
print("descending order is : ",l)
# Out:
# enter first key : 1
# enter second key : 2
# enter third key : 3
# enter fourth key : 4
# enter fifth key : 5
# enter first value : apple
# enter second value : grape
# enter third value : orange
# enter fourth value : jackfruit
# enter fifth value : guava
# ascending order is :  [('1', 'apple'), ('2', 'grape'), ('3', 'orange'), ('4', 'jackfruit'), ('5', 'guava')]
# descending order is :  [('5', 'guava'), ('4', 'jackfruit'), ('3', 'orange'), ('2', 'grape'), ('1', 'apple')]

# %%
x=input("enter the first string : ")
y=input("enter the second string : ")
def swapch(x,y): 
  a = y[:1] + x[1:]
  b = x[:1] + y[1:]
  return a + ' ' + b
print(swapch(x,y))
# Out:
# enter the first string : drop
# enter the second string : cope
# crop dope

# %%
c1=[]
x=int(input("enter limit for list1 :"))
for i in range(1,x+1):
  a=input()
  c1.append(a)
  p=set(c1)
print(p)
c2=[]
y=int(input("enter limit for list2 : "))
for i in range(1,y+1):
  b=input()
  c2.append(b)
  q=set(c2)
print(q)
print(p.difference(q))
# Out:
# enter limit for list1 :3
# green
# white
# blue
# {'blue', 'white', 'green'}
# enter limit for list2 : 2
# green
# orange
# {'orange', 'green '}
# {'blue', 'white', 'green'}

# %%
a=int(input("enter any integer : "))
n1=int("%s" %a)
n2=int("%s%s" %(a,a))
n3=int("%s%s%s" %(a,a,a))
print("value of n+nn+nnn is : ",n1+n2+n3)
# Out:
# enter any integer : 4
# value of n+nn+nnn is :  492

# %%
c=[]
x=int(input("enter limit for list : "))
for i in range(1,x+1):
  a=input()
  c.append(a)
print(c)
print(c[0],c[-1])
# Out:
# enter limit for list : 3
# black
# white
# blue
# ['black', 'white', 'blue']
# black blue

# %%
str=input("enter any string : ")
def rep_ch(str1):
  char=str1[0]
  str1=str1.replace(char, '$')
  str1=char+str1[1:]
  return str1
print(rep_ch(str))
# Out:
# enter any string : airoplane
# airopl$ne

# %%
x=[]
a=int(input("enter limit for list1 : "))
for i in range(1,a+1):
  a=int(input())
  x.append(a)
print(x)
y=[]
b=int(input("enter limit for list2 : "))
for i in range(1,b+1):
  b=int(input())
  y.append(b)
print(y)
if (len(x)==len(y)):
  print("list1 and list2 are of same length i.e.",len(x))
else:
  print("list1 and list2 are of different length.")
if (sum(x)==sum(y)):
  print("list1 and list2 sums to the same value i.e.",sum(x))
else:
  print("list1 and list2 sums up to different values.")
def common(x, y): 
    p=set(x) 
    q=set(y) 
    if len(p.intersection(q)) > 0: 
        return(p.intersection(q))   
    else: 
        return("no common elements")  
print("value that occur in both lists is/are :",common(x,y))
# Out:
# enter limit for list1 : 3
# 4
# 5
# 6
# [4, 5, 6]
# enter limit for list2 : 3
# 4
# 8
# 9
# [4, 8, 9]
# list1 and list2 are of same length i.e. 3
# list1 and list2 sums up to different values.
# value that occur in both lists is/are : {4}

# %%
l=[]
x=int(input("enter the limit : "))
for i in range (1,x+1):
  x=input("enter the first name : ")
  l.append(x)
  count = x.count('a')
  print("number of time a is present in name:",count)
# Out:
# enter the limit : 3
# enter the first name : akshay
# number of time a is present in name: 2
# enter the first name : akash
# number of time a is present in name: 2
# enter the first name : abin
# number of time a is present in name: 1

# %%
n=input("enter your house number : ")
hname=input("enter your house name : ")
s=input("enter your street name : ")
t=input("enter your town/city : ")
d=input("enter your district : ")
state=input("enter your state : ")
county=input("enter your county : ")
pin=int(input("enter your postcode: "))
print("\nAddress Details :\n" + "\nHousenumber :",n,"\nHouse :",hname,"\nStreet : ",s,"\nTown/City : ",t,"District : ",d,"\nState : ",state,"\nCounty : ",county,"\nPostcode : ",pin)
# Out:
# enter your house number : 25
# enter your house name : theppukallunkal
# enter your street name : nedumkunnam
# enter your town/city : karukachal
# enter your district : kottayam
# enter your state : kerala
# enter your county : india
# enter your postcode: 689589
#
# Address Details :
#
# Housenumber : 25
# House : theppukallunkal
# Street :  nedumkunnam
# Town/City :  karukachal District :  kottayam
# State :  kerala
# County :  india
# Postcode :  689589
