# %%
s=int(input("enter starting year"))
e=int(input("enter ending year"))
print("leap years between" ,s, "and" ,e)
while (s<=e):
  if ((s%400==0) or ((s%4==0) and (s%100!=0))):
    print(s)
  s=s+1
# Out:
# enter starting year2000
# enter ending year2021
# leap years between 2000 and 2021
# 2000
# 2004
# 2008
# 2012
# 2016
# 2020

# %%
n=input("enter your house number : ")
hname=input("enter your house name : ")
s=input("enter your street name : ")
t=input("enter your town/city : ")
d=input("enter your district : ")
state=input("enter your state : ")
county=input("enter your county : ")
pin=int(input("enter your postcode: "))
print("\nAddress Details :\n" + "\nHousenumber :",n,"\nHouse :",hname,"\nStreet : ",s,"\nTown/City : ",t,"District : ",d,"\nState : ",state,"\nCounty : ",county,"\nPostcode : ",pin)
# Out:
# enter your house number : 21
# enter your house name : akshay bhavan
# enter your street name : nedumkunnam
# enter your town/city : karukachal
# enter your district : kpttayam
# enter your state : kerala
# enter your county : india
# enter your postcode: 689589
#
# Address Details :
#
# Housenumber : 21
# House : akshay bhavan
# Street :  nedumkunnam
# Town/City :  karukachal District :  kpttayam
# State :  kerala
# County :  india
# Postcode :  689589

# %%
ls1=[10,-2,12,-8,9,15,20]
for num in ls1:
  if num>0:
    print(num,end= " ")
# Out:
# 10 12 9 15 20

# %%
num=int(input("Enter the number:"))
lis1=[]
for i in range(1,num+1):
    squr=i*i
    lis1.append(squr)
print(lis1)
# Out:
# Enter the number:4
# [1, 4, 9, 16]

# %%
word=(input("Enter a word:"))
vowel=[]
for i in range(0,len(word)):
  if (word[i]=='a' or word[i]=='A' or word[i]=='e' or word[i]=='E'
   or word[i]=='i' or word[i]=='I' or word[i]=='o' or word[i]=='O'
   or word[i]=='u' or word[i]=='U'):
    vow=word[i]
    vowel.append(vow)
print(vowel)
# Out:
# Enter a word:beautiful
# ['e', 'a', 'u', 'i', 'u']

# %%
word=input("Enter word:")
ord_val=[]
for i in range(0,len(word)):
  value=ord(word[i])
  ord_val.append(value)
print(ord_val)
# Out:
# Enter word:behind
# [98, 101, 104, 105, 110, 100]

# %%
line=input("\nEnter the line of string:")
part=input("\nEnter the word to count:")
count=line.count(part)
print("\nThe count of given word in given line is:",count)
# Out:
# Enter the line of string:4
#
# Enter the word to count:3
#
# The count of given word in given line is: 0

# %%
lst = []
n = int(input("Enter size of list or number of elements thet you wants to enter : "))
for i in range(0, n):
    elem = int(input("Enter element:"))
    if(elem>=100):
        lst.append('over')
    else:
        lst.append(elem)
print(lst)
# Out:
# Enter size of list or number of elements thet you wants to enter : 4
# Enter element:1
# Enter element:2
# Enter element:3
# Enter element:4
# [1, 2, 3, 4]

# %%
l=[]
x=int(input("Enter the limit:"))
for i in  range(1,x+1):
  x=input("enter the first name:")
  l.append(x)
  count=x.count('a')
  print("number of times 'a' in in name:",count)
# Out:
# Enter the limit:3
# enter the first name:abhi
# number of times 'a' in in name: 1
# enter the first name:akash
# number of times 'a' in in name: 2
# enter the first name:basu
# number of times 'a' in in name: 1

# %%
list1=[]
list2=[]
sum1=0
sum2=0
n=int(input("\nEnter the number of elements in 1st list:"))
for i in range(0,n):
    fnum=input("\nEnter the number:")
    list1.append(fnum)
n2=int(input("\nEnter the number of elements in 2nd list:"))
for j in range(0,n2):
    fnum2=input("\nEnter the number:")
    list2.append(fnum2)
if(len(list1)==len(list2)):
    print("\nBoth lists are of length:",len(list1))
else:
    print("\nThe lists are not of same length!!")
for k in range(0,n):
   sum1=sum1+int(list1[k])
for l in range(0,n2):
   sum2=sum2+int(list2[l])
if sum1==sum2:
    print("\nLists are of same sum!!")
else:
    print("\nlists are not of same sum!!")
for i in range(0,n):
    for j in range(0,n2):
        if(list1[i]==list2[j]):
            print("\n%s is present in both lists!"%list1[i])
        
print("\nNo repetition in lists!")
# Out:
# Enter the number of elements in 1st list:3
#
# Enter the number:9
#
# Enter the number:6
#
# Enter the number:3
#
# Enter the number of elements in 2nd list:3
#
# Enter the number:9
#
# Enter the number:7
#
# Enter the number:2
#
# Both lists are of length: 3
#
# Lists are of same sum!!
#
# 9 is present in both lists!
#
# No repetition in lists!

# %%
word=input("Enter String:")
ls=[]
ls.append(word[0])
for i in range(1,len(word)):
    if(word[i]==word[0]):
        ls.append('$')
    else:
        ls.append(word[i])
print(ls)
# Out:
# Enter String:onion
# ['o', 'n', 'i', '$', 'n']

# %%
word=input("Enter String:")
modified=word[-1]+word[1:-1]+word[0]
print(modified)
# Out:
# Enter String:cobol
# loboc

# %%
rad=int(input("Enter radius:"))
pi=3.14
area=pi*rad*rad
print("Area of circle"+str(area))
# Out:
# Enter radius:6
# Area of circle113.03999999999999

# %%
num1=int(input("Enter first number:"))
num2=int(input("Enter second number:"))
num3=int(input("Enter third number:"))
if num1>num2 and num1>num3:
  print("Greater number"+str(num1))
elif num2>num1 and num2>num3:
  print("Greater number"+str(num2))  
else:
  print("Greater number"+str(num3))
# Out:
# Enter first number:20
# Enter second number:25
# Enter third number:30
# Greater number30

# %%
filename = input("Input the Filename: ")
extension= filename.split(".")
print ("The extension of the file is : " + extension[-1])
# Out:
# Input the Filename: first.html
# The extension of the file is : html

# %%
colors=[]
limit=int(input("Enter number of colors:"))
for i in range(0,limit):
   co=input("Enter color:")
   colors.append(co)
print("first color:"+colors[0]+"\nlast color:"+colors[-1])
# Out:
# Enter number of colors:4
# Enter color:blue
# Enter color:pink
# Enter color:green
# Enter color:red
# first color:blue
# last color:red

# %%
n=int(input("Enter number:"))
sum = 0
for i in range(0, 3):
   sum = sum+int(str(n)+( i*str(n)))
print(sum)
# Out:
# Enter number:4
# 492

# %%
color_list_1 =set()
color_list_2 = set()
limit1=int(input("Enter l1 limit:"))
limit2=int(input("Enter l2 limit:"))
for i in range(0,limit1):
   color1=input("Enter color to l1:")
   color_list_1.add(color1)
for j in range(0,limit2):
   color2=input("Enter color to l2:")
   color_list_2.add(color2)
print(color_list_1.difference(color_list_2))
# Out:
# Enter l1 limit:3
# Enter l2 limit:3
# Enter color to l1:blue
# Enter color to l1:red
# Enter color to l1:black
# Enter color to l2:pink
# Enter color to l2:violrt
# Enter color to l2:yellow
# {'red', 'black', 'blue'}

# %%
def chars_mix_up(a, b):  
  new_a = b[:1] + a[1:]  
  new_b = a[:1] + b[1:]  
  
  return new_a + ' ' + new_b 
first=input("Enter word1:")
second=input("Enter word2:")   
print(chars_mix_up(first,second ))
# Out:
# Enter word1:flop
# Enter word2:drop
# dlop frop

# %%
y={'carl':40,'alan':2,'bob':1,'danny':3} 
                                         
l=list(y.items()) 
print("Dictionary:",l)
l.sort()          
print('Ascending order is',l)

l=list(y.items())
l.sort(reverse=True) 
print('Descending order is',l)
# Out:
# Dictionary: [('carl', 40), ('alan', 2), ('bob', 1), ('danny', 3)]
# Ascending order is [('alan', 2), ('bob', 1), ('carl', 40), ('danny', 3)]
# Descending order is [('danny', 3), ('carl', 40), ('bob', 1), ('alan', 2)]

# %%
dict1 = {  'Ritika': 5, 'Rithik': 7, 'Arjun' : 10 }
dict2 = {'Aadi': 8,'Sarath': 20,'Akash' : 11 }
dict1.update(dict2)
print('Updated dictionary 1 :')
print(dict1)
# Out:
# Updated dictionary 1 :
# {'Ritika': 5, 'Rithik': 7, 'Arjun': 10, 'Aadi': 8, 'Sarath': 20, 'Akash': 11}

# %%
num1 = int(input("Enter 1st number: "))
num2 = int(input("Enter 2nd number: "))
i = 1
while(i <= num1 and i <= num2):
  if(num1 % i == 0 and num2 % i == 0):
    gcd = i
  i = i + 1
print("GCD is", gcd)
# Out:
# Enter 1st number: 5
# Enter 2nd number: 15
# GCD is 5

# %%
list = [11, 22, 33, 44, 55]
print("\nOriginal list:")
print(list)
for i  in list:
	if(i%2 == 0):
	    list.remove(i)
print("\nlist after removing EVEN numbers:")
print(list)
# Out:
# Original list:
# [11, 22, 33, 44, 55]
#
# list after removing EVEN numbers:
# [11, 33, 55]
